# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("D:\\1-Data Science\\6 - Machine Learning\\Decision Tree\Data\\credit.csv")

# %%
df
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0             < 0 DM                     6       critical
# 1         1 - 200 DM                    48           good
# 2            unknown                    12       critical
# 3             < 0 DM                    42           good
# 4             < 0 DM                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996           < 0 DM                    30           good
# 997          unknown                    12           good
# 998           < 0 DM                    45           good
# 999       1 - 200 DM                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951        < 100 DM         1 - 4 years
# ...

# %%
df.head(11)
# Out:
#    checking_balance  months_loan_duration credit_history  \
# 0            < 0 DM                     6       critical
# 1        1 - 200 DM                    48           good
# 2           unknown                    12       critical
# 3            < 0 DM                    42           good
# 4            < 0 DM                    24           poor
# 5           unknown                    36           good
# 6           unknown                    24           good
# 7        1 - 200 DM                    36           good
# 8           unknown                    12           good
# 9        1 - 200 DM                    30       critical
# 10       1 - 200 DM                    12           good
#
#                  purpose  amount savings_balance employment_duration  \
# 0   furniture/appliances    1169         unknown           > 7 years
# 1   furniture/appliances    5951        < 100 DM         1 - 4 years
# 2              education    2096        < 100 DM         4 - 7 years
# ...

# %%
df.tail(11)
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 989       1 - 200 DM                    24       critical
# 990          unknown                    12       critical
# 991          unknown                    15      very good
# 992           < 0 DM                    18           good
# 993           < 0 DM                    36           good
# 994          unknown                    12           good
# 995          unknown                    12           good
# 996           < 0 DM                    30           good
# 997          unknown                    12           good
# 998           < 0 DM                    45           good
# 999       1 - 200 DM                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 989  furniture/appliances    1743        < 100 DM           > 7 years
# 990             education    3565         unknown            < 1 year
# ...

# %%
df.sample(11)
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 824          unknown                    18       critical
# 195       1 - 200 DM                     9       critical
# 333          unknown                    48       critical
# 336       1 - 200 DM                    13           good
# 725          unknown                     6       critical
# 276          unknown                    18       critical
# 887       1 - 200 DM                    48           good
# 14            < 0 DM                    15           good
# 953          unknown                    36           good
# 805           < 0 DM                    36           good
# 835           < 0 DM                    12        perfect
#
#                   purpose  amount savings_balance employment_duration  \
# 824  furniture/appliances    3780        < 100 DM            < 1 year
# 195             education    1501        < 100 DM           > 7 years
# ...

# %%
df.columns
# Out:
# Index(['checking_balance', 'months_loan_duration', 'credit_history', 'purpose',
#        'amount', 'savings_balance', 'employment_duration', 'percent_of_income',
#        'years_at_residence', 'age', 'other_credit', 'housing',
#        'existing_loans_count', 'job', 'dependents', 'phone', 'default'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
# ...

# %%
df.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3           < 0 DM                    42           good  furniture/appliances
# 4           < 0 DM                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951        < 100 DM         1 - 4 years                  2
# 2    2096        < 100 DM         4 - 7 years                  2
# 3    7882        < 100 DM         4 - 7 years                  2
# 4    4870        < 100 DM         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
df['employment_duration'] = df['employment_duration'].replace({"1 - 4 years":'low',"> 7 years":'high','4 - 7 years':'medium'})
df['checking_balance'] = df['checking_balance'].replace({'1 - 200 DM':'high','< 0 DM':'low'})
df['savings_balance'] = df['savings_balance'].replace({'< 100 DM':'low','100 - 500 DM':'high'})

# %%
df.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0              low                     6       critical  furniture/appliances
# 1             high                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3              low                    42           good  furniture/appliances
# 4              low                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown                high                  4
# 1    5951             low                 low                  2
# 2    2096             low              medium                  2
# 3    7882             low              medium                  2
# 4    4870             low                 low                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
le = LabelEncoder()

# %%
l = ['checking_balance','credit_history','purpose','savings_balance','employment_duration','other_credit','housing','job','phone']

for i in l:
    df[i] = le.fit_transform(df[i])

# %%
input = df.drop('default', axis = 'columns')
target = df['default']

# %%
X_train, X_test, y_train, y_test = train_test_split(input, target, test_size=0.2)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.72
